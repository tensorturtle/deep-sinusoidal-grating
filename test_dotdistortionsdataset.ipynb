# %%
from DotDistortionsDataset import *

dataset = DotDistortions(distortion_level='3',
length=100, 
train_like = False,
category_seeds = [119,423,237],
num_categories = 3,)

# %% [markdown]
# What's really cool is that there is a 2^32 number of distinct categories.
#
# Just supply the `category_seeds` with an integer and the the dataset will deterministically generate the same base dot pattern.

# %%
dataset.category_random_seeds
# Out:
# [119, 423, 237]

# %%
img, bbox, cat_seed = next(iter(dataset))

# %%
import matplotlib.pyplot as plt
plt.imshow(img, cmap='gray')

# %%
bbox
# Out:
# [{'category': 237, 'bbox': (400, 117, 466, 207)},
#  {'category': 'other', 'bbox': (420, 253, 504, 331)},
#  {'category': 'other', 'bbox': (214, 175, 292, 262)},
#  {'category': 'other', 'bbox': (391, 262, 472, 346)},
#  {'category': 'other', 'bbox': (242, 102, 317, 189)},
#  {'category': 'other', 'bbox': (475, 126, 544, 216)},
#  {'category': 'other', 'bbox': (276, 160, 324, 244)}]

# %%
cat_seed
# Out:
# 237

# %%
dataset = DotDistortions(distortion_level='3',
length=100, 
train_like = True,
category_seeds = None,
num_categories = 3,)

# %%
img, bbox, cat_seed = next(iter(dataset))

# %%
import matplotlib.pyplot as plt
plt.imshow(img, cmap='gray')
